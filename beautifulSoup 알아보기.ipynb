# %%
import bs4

# %%
bs4.__version__
# Out:
# '4.7.1'

# %%
from bs4 import BeautifulSoup as bs

# %%
html = """
<html><body>
<h1> 스크래핑이란!? </h1>
<p> 웹 페이지를 분류하기</p>
<p> 원하는 부분을 추출하는 것</p>
</body></html>
"""

# %%
soup = bs(html, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
h1 = soup.html.body.h1

# %%
type(h1)
# Out:
# bs4.element.Tag

# %%
h1
# Out:
# <h1> 스크래핑이란!? </h1>

# %%
h1.string
# Out:
# ' 스크래핑이란!? '

# %%
p1 = soup.html.body.p

# %%
p1
# Out:
# <p> 웹 페이지를 분류하기</p>

# %%
p1.string
# Out:
# ' 웹 페이지를 분류하기'

# %%
type(p1)
# Out:
# bs4.element.Tag

# %%
p2 = p1.next_sibling

# %%
p2
# Out:
# '\n'

# %%
type(p2)
# Out:
# bs4.element.NavigableString

# %%
p2.string
# Out:
# '\n'

# %%
p3 = p1.next_sibling.next_sibling

# %%
p3
# Out:
# <p> 원하는 부분을 추출하는 것</p>

# %%
p3.string
# Out:
# ' 원하는 부분을 추출하는 것'

# %% [markdown]
# ## id 로 검색하기 : find

# %%
html_1 = """
<html><body>
<h1 id='title'> 스크래핑이란!? </h1>
<p id="body"> 웹 페이지를 분류하기</p>
<p> 원하는 부분을 추출하는 것</p>
</body></html>
"""

# %%
soup = bs(html_1, 'html.parser')

# %%
title = soup.find(id="title")

# %%
title.string
# Out:
# ' 스크래핑이란!? '

# %%
body = soup.find(id="body")

# %%
body.string
# Out:
# ' 웹 페이지를 분류하기'

# %% [markdown]
# ## 여러 개의 요소 추출하기 : find_all

# %%
html_2 = """
<html><body>
<ul>
<li><a href="http://www.naver.com">naver</a></li>
<li><a href="http://www.daum.net">daumr</a></li>
<li><a href="http://www.sk.com">sk</a></li>
</ul>
</body></html>
"""

# %%
soup = bs(html_2, "html.parser")

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_most_recent_element',
# ...

# %%
soup
# Out:
# <html><body>
# <ul>
# <li><a href="http://www.naver.com">naver</a></li>
# <li><a href="http://www.daum.net">daumr</a></li>
# <li><a href="http://www.sk.com">sk</a></li>
# </ul>
# </body></html>

# %%
soup.prettify()
# Out:
# '<html>\n <body>\n  <ul>\n   <li>\n    <a href="http://www.naver.com">\n     naver\n    </a>\n   </li>\n   <li>\n    <a href="http://www.daum.net">\n     daumr\n    </a>\n   </li>\n   <li>\n    <a href="http://www.sk.com">\n     sk\n    </a>\n   </li>\n  </ul>\n </body>\n</html>\n'

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
links = soup.find_all("a")

# %%
type(links)
# Out:
# bs4.element.ResultSet

# %%
links.source.__dict__
# Out:
# {'name': 'a', 'attrs': {}, 'text': None}

# %% [markdown]
# ### 내부의 데이터를 전부 받기

# %%
[*links]
# Out:
# [<a href="http://www.naver.com">naver</a>,
#  <a href="http://www.daum.net">daumr</a>,
#  <a href="http://www.sk.com">sk</a>]

# %% [markdown]
# ### 내부를 순환하면서 처리하기

# %%
for a in links :
    print(a.attrs)
    href = a.attrs['href']
    text = a.string
    print(href ,"-->",text)
# Out:
# {'href': 'http://www.naver.com'}
# http://www.naver.com --> naver
# {'href': 'http://www.daum.net'}
# http://www.daum.net --> daumr
# {'href': 'http://www.sk.com'}
# http://www.sk.com --> sk

# %% [markdown]
# ## 데이터를 가져오기 : urlopen

# %%
import urllib.request as req

# %%
url = "http://www.naver.com"

# %%
res =  req.urlopen(url)

# %% [markdown]
# ## html 문서 파싱하기

# %%
soup = bs(res, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
class_ = soup.find_all("p")

# %%
class_
# Out:
# [<p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>,
#  <p class="dsc">ON/OFF설정은<br/>해당 기기(브라우저)에 저장됩니다.</p>,
#  <p class="func _atcmpBtnGroup"><span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span><span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span></p>,
#  <p class="info_words">현재 자동완성 기능을 사용하고 계십니다.</p>,
# ...

# %%
type(class_)
# Out:
# bs4.element.ResultSet

# %%
for a in  class_ :
    print(a.attrs, type(a.attrs))
    if 'class' in a.attrs :
        print(a.attrs['class'])
# Out:
# {'class': ['dsc']} <class 'dict'>
# ['dsc']
# {'class': ['dsc']} <class 'dict'>
# ['dsc']
# {'class': ['func', '_atcmpBtnGroup']} <class 'dict'>
# ['func', '_atcmpBtnGroup']
# {'class': ['info_words']} <class 'dict'>
# ['info_words']
# {'class': ['func', '_atcmpBtnGroup']} <class 'dict'>
# ['func', '_atcmpBtnGroup']
# {'class': ['info_words']} <class 'dict'>
# ['info_words']
# {'class': ['func', '_atcmpBtnGroup']} <class 'dict'>
# ['func', '_atcmpBtnGroup']
# {'class': ['info_words']} <class 'dict'>
# ['info_words']
# {'class': ['func', '_atcmpBtnGroup']} <class 'dict'>
# ['func', '_atcmpBtnGroup']
# {'class': ['info_words', '_offMsg'], 'style': 'display:none'} <class 'dict'>
# ['info_words', '_offMsg']
# {'class': ['info_words', '_offMsg'], 'style': 'display:none'} <class 'dict'>
# ['info_words', '_offMsg']
# {'class': ['noti', '_noti'], 'style': 'display:none'} <class 'dict'>
# ['noti', '_noti']
# {'class': ['func', '_recentBtnGroup']} <class 'dict'>
# ['func', '_recentBtnGroup']
# ...
